# %% [markdown]
# # ਉਦਾਹਰਨ ਨਮੂਨਾ ਹੋਟਲ ਅਤੇ ਫਲਾਈਟ ਬੁੱਕਿੰਗ ਏਜੰਟ
#
# ਇਹ ਹੱਲ ਤੁਹਾਨੂੰ ਫਲਾਈਟ ਟਿਕਟਾਂ ਅਤੇ ਹੋਟਲ ਬੁੱਕ ਕਰਨ ਵਿੱਚ ਮਦਦ ਕਰੇਗਾ। ਇਹ ਸਥਿਤੀ ਲੰਡਨ ਹੀਥਰੋ LHR ਤੋਂ ਨਿਊਯਾਰਕ JFK ਤੱਕ ਫਰਵਰੀ 20, 2024 ਨੂੰ ਯਾਤਰਾ ਕਰਨ ਅਤੇ ਫਰਵਰੀ 27, 2025 ਨੂੰ ਵਾਪਸ ਆਉਣ ਦੀ ਹੈ। ਯਾਤਰਾ ਸਿਰਫ ਬ੍ਰਿਟਿਸ਼ ਏਅਰਵੇਜ਼ ਨਾਲ ਅਰਥਵਿਵਸਥਾ ਸ਼੍ਰੇਣੀ ਵਿੱਚ ਹੋਵੇਗੀ। ਮੈਂ ਨਿਊਯਾਰਕ ਵਿੱਚ ਹਿਲਟਨ ਹੋਟਲ ਵਿੱਚ ਰਹਿਣਾ ਚਾਹੁੰਦਾ ਹਾਂ। ਕਿਰਪਾ ਕਰਕੇ ਫਲਾਈਟ ਅਤੇ ਹੋਟਲ ਦੇ ਖਰਚੇ ਪ੍ਰਦਾਨ ਕਰੋ।

# %% [markdown]
# # ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਸ਼ੁਰੂ ਕਰੋ ਅਤੇ **.env** ਤੋਂ ਕਨਫਿਗਰੇਸ਼ਨ ਜਾਣਕਾਰੀ ਪ੍ਰਾਪਤ ਕਰੋ
#
# ### **.env**
#
# ਇੱਕ .env ਫਾਈਲ ਬਣਾਓ
#
# **.env** ਵਿੱਚ ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਦੀ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ, AOAI ਦੁਆਰਾ ਵਰਤਿਆ ਗਿਆ ਮਾਡਲ, ਅਤੇ ਸੰਬੰਧਿਤ ਗੂਗਲ API ਸਰਚ ਸੇਵਾ API, ENDPOINT ਆਦਿ ਸ਼ਾਮਲ ਹੁੰਦੇ ਹਨ।
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "ਤੁਹਾਡੇ ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਮਾਡਲ ਡਿਪਲੌਇਮੈਂਟ ਦਾ ਨਾਮ"
#
# [**NOTE**] ਤੁਹਾਨੂੰ 100,000 ਰੇਟ ਲਿਮਿਟ (ਟੋਕਨ ਪ੍ਰਤੀ ਮਿੰਟ) ਅਤੇ 600 ਰੇਟ ਲਿਮਿਟ (ਰਿਕਵੈਸਟ ਪ੍ਰਤੀ ਮਿੰਟ) ਵਾਲਾ ਮਾਡਲ ਲੋੜੀਂਦਾ ਹੋਵੇਗਾ।
#
#   ਤੁਸੀਂ ਐਜ਼ਰ ਏਆਈ ਫਾਊਂਡਰੀ - ਮਾਡਲ ਅਤੇ ਐਂਡਪੌਇੰਟ ਵਿੱਚ ਮਾਡਲ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "ਤੁਹਾਡੇ ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਪ੍ਰੋਜੈਕਟ ਦੀ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ"
#
#   ਤੁਸੀਂ ਆਪਣੇ ਪ੍ਰੋਜੈਕਟ ਓਵਰਵਿਊ ਵਿੱਚ AI ਫਾਊਂਡਰੀ ਪੋਰਟਲ ਸਕ੍ਰੀਨ ਤੋਂ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।
#
# - **SERPAPI_SEARCH_API_KEY** = "ਤੁਹਾਡਾ SERPAPI ਸਰਚ API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "ਤੁਹਾਡਾ SERPAPI ਸਰਚ ENDPOINT"
#
# ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਦੇ ਮਾਡਲ ਡਿਪਲੌਇਮੈਂਟ ਨਾਮ ਅਤੇ ਪ੍ਰੋਜੈਕਟ ਕਨੈਕਸ਼ਨ ਸਟਰਿੰਗ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, ਤੁਹਾਨੂੰ ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਬਣਾਉਣੀ ਪਵੇਗੀ। ਇਹ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ ਕਿ ਤੁਸੀਂ ਇਸਨੂੰ ਸਿੱਧੇ ਬਣਾਉਣ ਲਈ [ਇਸ ਟੈਂਪਲੇਟ](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ਦੀ ਵਰਤੋਂ ਕਰੋ। （***ਨੋਟ:*** ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਸੇਵਾ ਵਰਤਮਾਨ ਵਿੱਚ ਸੀਮਿਤ ਖੇਤਰ ਵਿੱਚ ਸੈਟ ਕੀਤੀ ਗਈ ਹੈ। ਇਹ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ ਕਿ ਤੁਸੀਂ ਖੇਤਰ ਸੈਟ ਕਰਨ ਲਈ [ਇਸ ਲਿੰਕ](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ਨੂੰ ਵੇਖੋ।)
#
# ਏਜੰਟ ਨੂੰ SERPAPI ਤੱਕ ਪਹੁੰਚ ਦੀ ਲੋੜ ਹੈ। ਇਹ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ ਕਿ ਤੁਸੀਂ [ਇਸ ਲਿੰਕ](https://serpapi.com/searches) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਰਜਿਸਟਰ ਕਰੋ। ਰਜਿਸਟ੍ਰੇਸ਼ਨ ਤੋਂ ਬਾਅਦ, ਤੁਸੀਂ ਇੱਕ ਵਿਲੱਖਣ API KEY ਅਤੇ ENDPOINT ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹੋ।

# %% [markdown]
# # ਸੈਟਅੱਪ
#
# ਇਸ ਨੋਟਬੁੱਕ ਨੂੰ ਚਲਾਉਣ ਲਈ, ਤੁਹਾਨੂੰ ਯਕੀਨੀ ਬਣਾਉਣਾ ਹੋਵੇਗਾ ਕਿ ਤੁਸੀਂ ਲੋੜੀਂਦੀਆਂ ਲਾਇਬ੍ਰੇਰੀਆਂ ਨੂੰ `pip install -r requirements.txt` ਚਲਾ ਕੇ ਇੰਸਟਾਲ ਕਰ ਲਿਆ ਹੈ।

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# ਤੁਹਾਡੀ ਸੈਮੈਂਟਿਕ ਕਰਨਲ ਵਰਜਨ ਘੱਟੋ-ਘੱਟ 1.27.2 ਹੋਣੀ ਚਾਹੀਦੀ ਹੈ।

# %% [markdown]
# ਆਪਣੀ .env ਫਾਈਲ ਸੈਟਿੰਗ ਅਤੇ ਸਰੋਤ ਲੋਡ ਕਰੋ ਕਿਰਪਾ ਕਰਕੇ ਯਕੀਨੀ ਬਣਾਓ ਕਿ ਤੁਸੀਂ ਆਪਣੀਆਂ ਕੁੰਜੀਆਂ ਅਤੇ ਸੈਟਿੰਗ ਜੋੜੀਆਂ ਹਨ ਅਤੇ ਇੱਕ ਸਥਾਨਕ .env ਫਾਈਲ ਬਣਾਈ ਹੈ।

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # ਐਜ਼ਰ ਵਿੱਚ ਲੌਗਿਨ ਕਰੋ
#
# ਹੁਣ ਤੁਹਾਨੂੰ ਐਜ਼ਰ ਵਿੱਚ ਲੌਗਿਨ ਕਰਨ ਦੀ ਲੋੜ ਹੈ। ਇੱਕ ਟਰਮੀਨਲ ਖੋਲ੍ਹੋ ਅਤੇ ਹੇਠਾਂ ਦਿੱਤਾ ਕਮਾਂਡ ਚਲਾਓ:
#
# ```bash
# az login
# ```
#
# ਇਹ ਕਮਾਂਡ ਤੁਹਾਨੂੰ ਆਪਣੇ ਐਜ਼ਰ ਪ੍ਰਮਾਣ ਪੱਤਰ ਦਰਜ ਕਰਨ ਲਈ ਕਹੇਗੀ, ਜਿਸ ਨਾਲ ਐਜ਼ਰ AI ਏਜੰਟ ਸੇਵਾ ਸਹੀ ਤਰੀਕੇ ਨਾਲ ਕੰਮ ਕਰ ਸਕੇ।

# %% [markdown]
# # ਵਿਆਖਿਆ:
# ਇਹ ਇੱਕ ਵੈਰੀਏਬਲ ਹੈ ਜੋ SERP (ਸਰਚ ਇੰਜਨ ਰਿਜ਼ਲਟਸ ਪੇਜ) API ਸੇਵਾ ਤੱਕ ਪਹੁੰਚ ਕਰਨ ਲਈ API ਕੁੰਜੀ ਸਟੋਰ ਕਰਦੀ ਹੈ। API ਕੁੰਜੀ ਇੱਕ ਵਿਲੱਖਣ ਪਛਾਣਕਰਤਾ ਹੈ ਜੋ ਤੁਹਾਡੇ ਖਾਤੇ ਨਾਲ ਸੰਬੰਧਿਤ ਬੇਨਤੀਆਂ ਦੀ ਪ੍ਰਮਾਣਿਕਤਾ ਲਈ ਵਰਤੀ ਜਾਂਦੀ ਹੈ।
#
# ਉਦੇਸ਼: ਇਸ ਲਾਈਨ ਦਾ ਉਦੇਸ਼ API ਕੁੰਜੀ ਨੂੰ ਇੱਕ ਵੈਰੀਏਬਲ ਵਿੱਚ ਸਟੋਰ ਕਰਨਾ ਹੈ ਤਾਂ ਜੋ ਇਸਨੂੰ SERP API ਸੇਵਾ ਤੱਕ ਬੇਨਤੀਆਂ ਦੀ ਪ੍ਰਮਾਣਿਕਤਾ ਲਈ ਵਰਤਿਆ ਜਾ ਸਕੇ। ਸੇਵਾ ਤੱਕ ਪਹੁੰਚ ਕਰਨ ਅਤੇ ਖੋਜਾਂ ਕਰਨ ਲਈ API ਕੁੰਜੀ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ।
#
# SERP API ਕੁੰਜੀ ਕਿਵੇਂ ਪ੍ਰਾਪਤ ਕਰੀਏ: SERP API ਕੁੰਜੀ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ, https://serpapi.com 'ਤੇ ਇਹ ਆਮ ਕਦਮ ਅਨੁਸਰਣ ਕਰੋ (ਜੋ ਸਟੈਪ ਤੁਹਾਡੇ ਵਰਤੇ ਜਾ ਰਹੇ ਖਾਸ SERP API ਸੇਵਾ 'ਤੇ ਨਿਰਭਰ ਕਰ ਸਕਦੇ ਹਨ):
#
# 1. SERP API ਸੇਵਾ ਚੁਣੋ: ਕਈ SERP API ਸੇਵਾਵਾਂ ਉਪਲਬਧ ਹਨ, ਜਿਵੇਂ ਕਿ SerpAPI, Google Custom Search JSON API, ਅਤੇ ਹੋਰ। ਉਹ ਚੁਣੋ ਜੋ ਤੁਹਾਡੇ ਜ਼ਰੂਰਤਾਂ ਲਈ ਸਭ ਤੋਂ ਵਧੀਆ ਹੋਵੇ।
#
# 2. ਖਾਤੇ ਲਈ ਸਾਈਨ ਅਪ ਕਰੋ: ਚੁਣੀ ਗਈ SERP API ਸੇਵਾ ਦੀ ਵੈਬਸਾਈਟ 'ਤੇ ਜਾਓ ਅਤੇ ਖਾਤੇ ਲਈ ਸਾਈਨ ਅਪ ਕਰੋ। ਤੁਹਾਨੂੰ ਕੁਝ ਬੁਨਿਆਦੀ ਜਾਣਕਾਰੀ ਦੇਣੀ ਪੈ ਸਕਦੀ ਹੈ ਅਤੇ ਆਪਣਾ ਈਮੇਲ ਪਤਾ ਪ੍ਰਮਾਣਿਤ ਕਰਨਾ ਪੈ ਸਕਦਾ ਹੈ।
#
# 3. API ਕੁੰਜੀ ਬਣਾਓ: ਸਾਈਨ ਅਪ ਕਰਨ ਤੋਂ ਬਾਅਦ, ਆਪਣੇ ਖਾਤੇ ਵਿੱਚ ਲੌਗਇਨ ਕਰੋ ਅਤੇ API ਸੈਕਸ਼ਨ ਜਾਂ ਡੈਸ਼ਬੋਰਡ 'ਤੇ ਜਾਓ। ਨਵੀਂ API ਕੁੰਜੀ ਬਣਾਉਣ ਜਾਂ ਜਨਰੇਟ ਕਰਨ ਦਾ ਵਿਕਲਪ ਲੱਭੋ।
#
# 4. API ਕੁੰਜੀ ਨੂੰ ਆਪਣੇ .env ਫਾਈਲ ਵਿੱਚ ਕਾਪੀ ਕਰੋ।

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # ਵਿਆਖਿਆ:
# BASE_URL: ਇਹ ਇੱਕ ਵੈਰੀਏਬਲ ਹੈ ਜੋ SERP API ਐਂਡਪੌਇੰਟ ਲਈ ਬੇਸ URL ਨੂੰ ਸਟੋਰ ਕਰਦਾ ਹੈ। ਵੈਰੀਏਬਲ ਦਾ ਨਾਮ BASE_URL ਇਸ ਗੱਲ ਨੂੰ ਦਰਸਾਉਣ ਲਈ ਵਰਤਿਆ ਜਾਂਦਾ ਹੈ ਕਿ ਇਹ URL API ਰਿਕਵੈਸਟਾਂ ਕਰਨ ਲਈ ਸ਼ੁਰੂਆਤੀ ਬਿੰਦੂ ਹੈ।
# 'https://serpapi.com/search':
#
# ਇਹ ਅਸਲ URL ਸਟਰਿੰਗ ਹੈ ਜੋ BASE_URL ਵੈਰੀਏਬਲ ਨੂੰ ਸੌਂਪੀ ਗਈ ਹੈ। ਇਹ SERP API ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਖੋਜ ਕਵੈਰੀਆਂ ਕਰਨ ਲਈ ਐਂਡਪੌਇੰਟ ਨੂੰ ਦਰਸਾਉਂਦੀ ਹੈ।
#
# # ਮਕਸਦ:
# ਇਸ ਲਾਈਨ ਦਾ ਮਕਸਦ ਇੱਕ ਕਾਂਸਟੈਂਟ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਨਾ ਹੈ ਜੋ SERP API ਲਈ ਬੇਸ URL ਨੂੰ ਰੱਖਦਾ ਹੈ। ਇਹ URL ਖੋਜ ਸੰਚਾਲਨ ਕਰਨ ਲਈ API ਰਿਕਵੈਸਟਾਂ ਬਣਾਉਣ ਦੇ ਸ਼ੁਰੂਆਤੀ ਬਿੰਦੂ ਵਜੋਂ ਵਰਤਿਆ ਜਾਵੇਗਾ।
#
# # ਵਰਤੋਂ:
# ਬੇਸ URL ਨੂੰ ਇੱਕ ਵੈਰੀਏਬਲ ਵਿੱਚ ਪਰਿਭਾਸ਼ਿਤ ਕਰਕੇ, ਤੁਸੀਂ ਇਸਨੂੰ ਆਪਣੇ ਕੋਡ ਵਿੱਚ ਕਿਤੇ ਵੀ ਦੁਬਾਰਾ ਵਰਤ ਸਕਦੇ ਹੋ ਜਿੱਥੇ ਵੀ ਤੁਹਾਨੂੰ SERP API ਨੂੰ ਰਿਕਵੈਸਟ ਭੇਜਣ ਦੀ ਲੋੜ ਹੋਵੇ। ਇਸ ਨਾਲ ਤੁਹਾਡਾ ਕੋਡ ਜ਼ਿਆਦਾ ਸੰਭਾਲਯੋਗ ਬਣ ਜਾਂਦਾ ਹੈ ਅਤੇ ਕਈ ਥਾਵਾਂ 'ਤੇ URL ਨੂੰ ਹਾਰਡਕੋਡ ਕਰਨ ਨਾਲ ਹੋਣ ਵਾਲੀਆਂ ਗਲਤੀਆਂ ਦਾ ਖਤਰਾ ਘਟ ਜਾਂਦਾ ਹੈ। ਮੌਜੂਦਾ ਉਦਾਹਰਨ https://serpapi.com/search?engine=bing ਹੈ ਜੋ Bing ਖੋਜ API ਦੀ ਵਰਤੋਂ ਕਰ ਰਿਹਾ ਹੈ। ਵੱਖ-ਵੱਖ API ਨੂੰ https://Serpapi.com 'ਤੇ ਚੁਣਿਆ ਜਾ ਸਕਦਾ ਹੈ।

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # ਵਿਆਖਿਆ:
#
# ਇਹ ਉਹ ਜਗ੍ਹਾ ਹੈ ਜਿੱਥੇ ਤੁਹਾਡਾ ਪਲੱਗਇਨ ਕੋਡ ਸਥਿਤ ਹੈ।
#
# ਕਲਾਸ ਪਰਿਭਾਸ਼ਾ: `class BookingPlugin`: ਇੱਕ ਕਲਾਸ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ ਜਿਸਦਾ ਨਾਮ BookingPlugin ਹੈ, ਜੋ ਹੋਟਲ ਅਤੇ ਫਲਾਈਟ ਬੁਕਿੰਗ ਲਈ ਵਿਧੀਆਂ ਸ਼ਾਮਲ ਕਰਦਾ ਹੈ।
#
# ਹੋਟਲ ਬੁਕਿੰਗ ਵਿਧੀ:
#
# - `@kernel_function(description="booking hotel")`: ਇੱਕ ਡੈਕੋਰੇਟਰ ਜੋ ਫੰਕਸ਼ਨ ਨੂੰ ਹੋਟਲ ਬੁਕਿੰਗ ਲਈ ਕਰਨਲ ਫੰਕਸ਼ਨ ਵਜੋਂ ਵਰਣਨ ਕਰਦਾ ਹੈ।
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: ਹੋਟਲ ਬੁਕਿੰਗ ਲਈ ਇੱਕ ਵਿਧੀ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ ਜਿਸ ਵਿੱਚ ਐਨੋਟੇਟ ਕੀਤੇ ਪੈਰਾਮੀਟਰ ਅਤੇ ਵਾਪਸੀ ਦੀ ਕਿਸਮ ਸ਼ਾਮਲ ਹੈ।
#
# ਇਹ ਵਿਧੀ ਹੋਟਲ ਬੁਕਿੰਗ ਬੇਨਤੀ ਲਈ ਪੈਰਾਮੀਟਰਾਂ ਦਾ ਇੱਕ ਡਿਕਸ਼ਨਰੀ ਬਣਾਉਂਦੀ ਹੈ ਅਤੇ SERP API ਨੂੰ ਇੱਕ GET ਬੇਨਤੀ ਭੇਜਦੀ ਹੈ। ਇਹ ਜਵਾਬ ਦੀ ਸਥਿਤੀ ਦੀ ਜਾਂਚ ਕਰਦੀ ਹੈ ਅਤੇ ਜੇ ਸਫਲ ਹੋਵੇ ਤਾਂ ਹੋਟਲ ਦੀਆਂ ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ ਵਾਪਸ ਕਰਦੀ ਹੈ, ਜਾਂ ਜੇ ਬੇਨਤੀ ਅਸਫਲ ਹੋਵੇ ਤਾਂ None ਵਾਪਸ ਕਰਦੀ ਹੈ।
#
# ਫਲਾਈਟ ਬੁਕਿੰਗ ਵਿਧੀ:
#
# - `@kernel_function(description="booking flight")`: ਇੱਕ ਡੈਕੋਰੇਟਰ ਜੋ ਫੰਕਸ਼ਨ ਨੂੰ ਫਲਾਈਟ ਬੁਕਿੰਗ ਲਈ ਕਰਨਲ ਫੰਕਸ਼ਨ ਵਜੋਂ ਵਰਣਨ ਕਰਦਾ ਹੈ।
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: ਫਲਾਈਟ ਬੁਕਿੰਗ ਲਈ ਇੱਕ ਵਿਧੀ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ ਜਿਸ ਵਿੱਚ ਐਨੋਟੇਟ ਕੀਤੇ ਪੈਰਾਮੀਟਰ ਅਤੇ ਵਾਪਸੀ ਦੀ ਕਿਸਮ ਸ਼ਾਮਲ ਹੈ।
#
# ਇਹ ਵਿਧੀ ਬਾਹਰ ਜਾਣ ਅਤੇ ਵਾਪਸੀ ਦੀ ਫਲਾਈਟ ਬੇਨਤੀਆਂ ਲਈ ਪੈਰਾਮੀਟਰਾਂ ਦੇ ਡਿਕਸ਼ਨਰੀ ਬਣਾਉਂਦੀ ਹੈ ਅਤੇ SERP API ਨੂੰ GET ਬੇਨਤੀਆਂ ਭੇਜਦੀ ਹੈ। ਇਹ ਜਵਾਬ ਦੀ ਸਥਿਤੀ ਦੀ ਜਾਂਚ ਕਰਦੀ ਹੈ ਅਤੇ ਜੇ ਸਫਲ ਹੋਵੇ ਤਾਂ ਫਲਾਈਟ ਜਾਣਕਾਰੀ ਨੂੰ ਨਤੀਜੇ ਦੇ ਸਤਰ ਵਿੱਚ ਸ਼ਾਮਲ ਕਰਦੀ ਹੈ, ਜਾਂ ਜੇ ਬੇਨਤੀ ਅਸਫਲ ਹੋਵੇ ਤਾਂ ਇੱਕ ਗਲਤੀ ਸੁਨੇਹਾ ਪ੍ਰਿੰਟ ਕਰਦੀ ਹੈ। ਇਹ ਵਿਧੀ ਨਤੀਜੇ ਦੇ ਸਤਰ ਨੂੰ ਵਾਪਸ ਕਰਦੀ ਹੈ ਜਿਸ ਵਿੱਚ ਫਲਾਈਟ ਜਾਣਕਾਰੀ ਸ਼ਾਮਲ ਹੁੰਦੀ ਹੈ।

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # ਵਿਆਖਿਆ:
# ਇੰਪੋਰਟ ਸਟੇਟਮੈਂਟਸ: Azure ਸਨਦਾਂ, AI ਏਜੰਟ, ਚੈਟ ਸੁਨੇਹਾ ਸਮੱਗਰੀ, ਲੇਖਕ ਦੀ ਭੂਮਿਕਾ, ਅਤੇ kernel function decorator ਲਈ ਲੋੜੀਂਦੇ ਮੌਡੀਊਲਾਂ ਨੂੰ ਇੰਪੋਰਟ ਕਰੋ।
#
# ਅਸਿੰਕ੍ਰੋਨਸ ਸੰਦਰਭ ਪ੍ਰਬੰਧਕ: async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,): ਇਹ ਇੱਕ ਅਸਿੰਕ੍ਰੋਨਸ ਸੰਦਰਭ ਪ੍ਰਬੰਧਕ ਸੈੱਟ ਕਰਦਾ ਹੈ ਜੋ Azure ਸਨਦਾਂ ਨੂੰ ਸੰਭਾਲਦਾ ਹੈ ਅਤੇ ਇੱਕ AI ਏਜੰਟ ਕਲਾਇੰਟ ਬਣਾਉਂਦਾ ਹੈ।
#
# ਏਜੰਟ ਦਾ ਨਾਮ ਅਤੇ ਹਦਾਇਤਾਂ:
# - `AGENT_NAME = "BookingAgent"`: ਏਜੰਟ ਦਾ ਨਾਮ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
# - `AGENT_INSTRUCTIONS = """..."""`: ਏਜੰਟ ਨੂੰ ਬੁਕਿੰਗ ਬੇਨਤੀਆਂ ਨੂੰ ਸੰਭਾਲਣ ਲਈ ਵਿਸਥਾਰਪੂਰਵਕ ਹਦਾਇਤਾਂ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ।
#
# ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ ਬਣਾਓ: `agent_definition = await client.agents.create_agent(...)`: ਨਿਰਧਾਰਿਤ ਮਾਡਲ, ਨਾਮ, ਅਤੇ ਹਦਾਇਤਾਂ ਨਾਲ ਇੱਕ ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ ਬਣਾਉਂਦਾ ਹੈ।
#
# AzureAI ਏਜੰਟ ਬਣਾਓ: `agent = AzureAIAgent(...)`: ਕਲਾਇੰਟ, ਏਜੰਟ ਪਰਿਭਾਸ਼ਾ, ਅਤੇ ਪਰਿਭਾਸ਼ਿਤ ਪਲੱਗਇਨ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਇੱਕ AzureAI ਏਜੰਟ ਬਣਾਉਂਦਾ ਹੈ।
#
# ਥ੍ਰੈਡ ਬਣਾਓ: `thread: AzureAIAgentThread | None = None`: ਏਜੰਟ ਲਈ ਇੱਕ ਥ੍ਰੈਡ ਬਣਾਓ। ਪਹਿਲਾਂ ਥ੍ਰੈਡ ਬਣਾਉਣ ਦੀ ਲੋੜ ਨਹੀਂ ਹੈ - ਜੇ `None` ਦੀ ਮੁੱਲ ਦਿੱਤੀ ਜਾਂਦੀ ਹੈ, ਤਾਂ ਪਹਿਲੀ ਕਾਲ ਦੇ ਦੌਰਾਨ ਇੱਕ ਨਵਾਂ ਥ੍ਰੈਡ ਬਣਾਇਆ ਜਾਵੇਗਾ ਅਤੇ ਜਵਾਬ ਦੇ ਹਿੱਸੇ ਵਜੋਂ ਵਾਪਸ ਕੀਤਾ ਜਾਵੇਗਾ।
#
# ਯੂਜ਼ਰ ਇਨਪੁਟਸ: `user_inputs = ["..."]`: ਏਜੰਟ ਦੁਆਰਾ ਪ੍ਰਕਿਰਿਆ ਕਰਨ ਲਈ ਯੂਜ਼ਰ ਇਨਪੁਟਸ ਦੀ ਸੂਚੀ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦਾ ਹੈ।
#
# ਅੰਤ ਵਿੱਚ, ਸਾਧਨਾਂ ਨੂੰ ਸਾਫ ਕਰਨ ਲਈ ਥ੍ਰੈਡ ਅਤੇ ਏਜੰਟ ਨੂੰ ਹਟਾਓ।

# %% [markdown]
# # ਪ੍ਰਮਾਣਿਕਤਾ
#
# `DefaultAzureCredential` ਕਲਾਸ Azure SDK ਲਈ Python ਦਾ ਹਿੱਸਾ ਹੈ। ਇਹ Azure ਸੇਵਾਵਾਂ ਨਾਲ ਪ੍ਰਮਾਣਿਕਤਾ ਪ੍ਰਾਪਤ ਕਰਨ ਦਾ ਇੱਕ ਮੂਲ ਤਰੀਕਾ ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ। ਇਹ ਖਾਸ ਕ੍ਰਮ ਵਿੱਚ ਕਈ ਤਰੀਕਿਆਂ ਨਾਲ ਪ੍ਰਮਾਣਿਕਤਾ ਕਰਨ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦੀ ਹੈ, ਜਿਵੇਂ ਕਿ ਵਾਤਾਵਰਣ ਚਰ, ਮੈਨੇਜਡ ਆਈਡੈਂਟਿਟੀ, ਅਤੇ Azure CLI ਪ੍ਰਮਾਣਿਕਤਾ।
#
# ਅਸਿੰਕ੍ਰੋਨ ਕਾਰਵਾਈਆਂ: aio ਮੋਡਿਊਲ ਦਰਸਾਉਂਦਾ ਹੈ ਕਿ DefaultAzureCredential ਕਲਾਸ ਅਸਿੰਕ੍ਰੋਨ ਕਾਰਵਾਈਆਂ ਦਾ ਸਮਰਥਨ ਕਰਦੀ ਹੈ। ਇਸਦਾ ਮਤਲਬ ਹੈ ਕਿ ਤੁਸੀਂ ਇਸਨੂੰ asyncio ਨਾਲ ਵਰਤ ਕੇ ਗੈਰ-ਅਵਰੋਧਕ ਪ੍ਰਮਾਣਿਕਤਾ ਬੇਨਤੀ ਕਰ ਸਕਦੇ ਹੋ।

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# **ਅਸਵੀਕਾਰਨਾ**:
# ਇਹ ਦਸਤਾਵੇਜ਼ AI ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਦਿਓ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸੁਚਨਾਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਨੂੰ ਇਸਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਤ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਇਸ ਅਨੁਵਾਦ ਦੀ ਵਰਤੋਂ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੇ ਕਿਸੇ ਵੀ ਗਲਤ ਫਹਿਮੀ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆ ਲਈ ਅਸੀਂ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
