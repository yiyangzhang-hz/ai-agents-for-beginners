# %% [markdown]
# # Mfano wa Wakala wa Kuhifadhi Hoteli na Ndege
#
# Suluhisho hili litakusaidia kuhifadhi tiketi za ndege na hoteli. Hali ni safari kutoka London Heathrow LHR tarehe 20 Februari 2024 kwenda New York JFK, kurudi tarehe 27 Februari 2025, ukisafiri daraja la uchumi na shirika la ndege la British Airways pekee. Ninataka kukaa katika hoteli ya Hilton huko New York, tafadhali toa gharama za ndege na hoteli.

# %% [markdown]
# # Anzisha Huduma ya Azure AI Agent na pata taarifa za usanidi kutoka **.env**
#
# ### **.env**
#
# Tengeneza faili la .env
#
# **.env** lina kamba ya muunganisho wa Huduma ya Azure AI Agent, mfano unaotumiwa na AOAI, na huduma ya API ya Utafutaji ya Google inayolingana, ENDPOINT, nk.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Jina la Uwekaji wa Mfano wa Huduma ya Azure AI Agent"
#
# [**NOTE**] Utahitaji mfano wenye Kiwango cha Kiwango cha 100,000 (Tokeni kwa dakika) Kiwango cha Kiwango cha 600 (Ombi kwa dakika)
#
#   Unaweza kupata mfano katika Azure AI Foundry - Mfano na Endpoint.
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Kamba ya Muunganisho wa Mradi wa Huduma ya Azure AI Agent"
#
#   Unaweza kupata kamba ya muunganisho wa mradi katika muhtasari wa mradi wako kwenye Skrini ya Portal ya AI ​​Foundry.
#
# - **SERPAPI_SEARCH_API_KEY** = "API KEY yako ya Utafutaji ya SERPAPI"
# - **SERPAPI_SEARCH_ENDPOINT** = "Endpoint yako ya Utafutaji ya SERPAPI"
#
# Ili kupata Jina la Uwekaji wa Mfano na Kamba ya Muunganisho wa Mradi wa Huduma ya Azure AI Agent, unahitaji kuunda Huduma ya Azure AI Agent. Inapendekezwa kutumia [kiolezo hiki](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) kuunda moja kwa moja （***Kumbuka:*** Huduma ya Azure AI Agent kwa sasa imewekwa katika eneo lililozuiliwa. Inapendekezwa kwamba uangalie [kiungo hiki](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) kuweka eneo)
#
# Wakala anahitaji kufikia SERPAPI. Inapendekezwa kujiandikisha kwa kutumia [kiungo hiki](https://serpapi.com/searches). Baada ya kujiandikisha, unaweza kupata API KEY ya kipekee na ENDPOINT

# %% [markdown]
# # Usanidi
#
# Ili kuendesha daftari hili, unahitaji kuhakikisha kuwa umesakinisha maktaba zinazohitajika kwa kuendesha `pip install -r requirements.txt`.

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# Toleo lako la Semantic Kernel linapaswa kuwa angalau 1.27.2.

# %% [markdown]
# Pakia faili yako ya .env na rasilimali tafadhali hakikisha umeongeza funguo zako na mipangilio na umeunda faili ya .env ya ndani.

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Ingia kwenye Azure
#
# Sasa unahitaji kuingia kwenye Azure. Fungua terminali na endesha amri ifuatayo:
#
# ```bash
# az login
# ```
#
# Amri hii itakuomba uingize maelezo yako ya kuingia ya Azure, ikiruhusu huduma ya Azure AI Agent kufanya kazi ipasavyo.

# %% [markdown]
# # Maelezo:
# Hii ni kigezo kinachohifadhi API key kwa ajili ya kufikia huduma ya SERP (Search Engine Results Page) API. API key ni kitambulisho cha kipekee kinachotumika kuthibitisha maombi yanayohusiana na akaunti yako.
#
# Madhumuni: Madhumuni ya mstari huu ni kuhifadhi API key katika kigezo ili iweze kutumika kuthibitisha maombi kwa huduma ya SERP API. API key inahitajika ili kufikia huduma na kufanya utafutaji.
# Jinsi ya Kupata API Key ya SERP: Ili kupata API key ya SERP, fuata hatua hizi za jumla kwenye https://serpapi.com (hatua halisi zinaweza kutofautiana kulingana na huduma maalum ya SERP API unayotumia):
#
# Chagua Huduma ya SERP API: Kuna huduma kadhaa za SERP API zinazopatikana, kama vile SerpAPI, Google Custom Search JSON API, na nyinginezo. Chagua ile inayokidhi mahitaji yako vyema.
#
# Jisajili kwa Akaunti: Nenda kwenye tovuti ya huduma ya SERP API uliyoiamua na ujisajili kwa akaunti. Huenda ukahitajika kutoa taarifa za msingi na kuthibitisha anwani yako ya barua pepe.
#
# Tengeneza API Key: Baada ya kujisajili, ingia kwenye akaunti yako na nenda kwenye sehemu ya API au dashibodi. Tafuta chaguo la kutengeneza au kuzalisha API key mpya.
# Nakili API Key kwenye faili yako ya .env.

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # Maelezo:
# BASE_URL: Hii ni kigezo kinachohifadhi URL ya msingi kwa endpoint ya SERP API. Jina la kigezo BASE_URL ni utaratibu unaotumika kuonyesha kwamba URL hii ni sehemu ya kuanzia kwa kufanya maombi ya API.
# 'https://serpapi.com/search':
#
# Hii ni mfuatano halisi wa URL uliowekwa kwenye kigezo BASE_URL. Inawakilisha endpoint ya kutekeleza maswali ya utafutaji kwa kutumia SERP API.
#
# # Kusudi:
# Kusudi la mstari huu ni kufafanua thamani isiyobadilika inayoshikilia URL ya msingi kwa SERP API. URL hii itatumika kama sehemu ya kuanzia kwa kujenga maombi ya API ili kutekeleza shughuli za utafutaji.
#
# # Matumizi:
# Kwa kufafanua URL ya msingi ndani ya kigezo, unaweza kuitumia tena kwa urahisi katika msimbo wako kila unapohitaji kufanya maombi kwa SERP API. Hii inafanya msimbo wako kuwa rahisi kudumisha na inapunguza hatari ya makosa yanayotokana na kuweka URL moja kwa moja mara nyingi. Mfano wa sasa ni https://serpapi.com/search?engine=bing ambayo inatumia Bing search API. API tofauti inaweza kuchaguliwa kwenye https://Serpapi.com

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # Maelezo:
#
# Hapa ndipo msimbo wa programu-jalizi yako unapatikana.
#
# Ufafanuzi wa Darasa: `class BookingPlugin`: Hufafanua darasa linaloitwa BookingPlugin ambalo lina mbinu za kuhifadhi hoteli na safari za ndege.
#
# Mbinu ya Kuhifadhi Hoteli:
#
# - `@kernel_function(description="booking hotel")`: Kidekoreta kinachoelezea kazi kama kazi ya kernel kwa kuhifadhi hoteli.
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: Hufafanua mbinu ya kuhifadhi hoteli na vigezo vilivyo na maelezo na aina ya matokeo.
#
# Mbinu hii huunda kamusi ya vigezo kwa ombi la kuhifadhi hoteli na kutuma ombi la GET kwa API ya SERP. Inakagua hali ya majibu na kurudisha mali za hoteli ikiwa imefanikiwa, au None ikiwa ombi limefeli.
#
# Mbinu ya Kuhifadhi Safari za Ndege:
#
# - `@kernel_function(description="booking flight")`: Kidekoreta kinachoelezea kazi kama kazi ya kernel kwa kuhifadhi safari za ndege.
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: Hufafanua mbinu ya kuhifadhi safari za ndege na vigezo vilivyo na maelezo na aina ya matokeo.
#
# Mbinu hii huunda kamusi za vigezo kwa maombi ya safari za ndege za kwenda na kurudi na kutuma maombi ya GET kwa API ya SERP. Inakagua hali ya majibu na kuongeza taarifa za safari za ndege kwenye mfuatano wa matokeo ikiwa imefanikiwa, au kuchapisha ujumbe wa kosa ikiwa ombi limefeli. Mbinu hii inarudisha mfuatano wa matokeo unaojumuisha taarifa za safari za ndege.

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # Maelezo:
# Vingizo vya Uagizaji: Ingiza moduli muhimu kwa ajili ya Azure credentials, AI agent, maudhui ya ujumbe wa mazungumzo, jukumu la mwandishi, na mapambo ya kazi ya kernel.
#
# Meneja wa Muktadha wa Asynchronous: `async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,)`: Hii huanzisha meneja wa muktadha wa asynchronous kushughulikia Azure credentials na kuunda mteja wa AI agent.
#
# Jina la Wakala na Maelekezo:
# - `AGENT_NAME = "BookingAgent"`: Hufafanua jina la wakala.
# - `AGENT_INSTRUCTIONS = """..."""`: Hutoa maelekezo ya kina kwa wakala kuhusu jinsi ya kushughulikia maombi ya uhifadhi.
#
# Unda Ufafanuzi wa Wakala: `agent_definition = await client.agents.create_agent(...)`: Huunda ufafanuzi wa wakala kwa kutumia mfano, jina, na maelekezo yaliyobainishwa.
#
# Unda Wakala wa AzureAI: `agent = AzureAIAgent(...)`: Huunda wakala wa AzureAI kwa kutumia mteja, ufafanuzi wa wakala, na programu-jalizi iliyobainishwa.
#
# Unda Thread: `thread: AzureAIAgentThread | None = None`: Unda thread kwa ajili ya wakala. Sio lazima kuunda thread kwanza - ikiwa thamani ya `None` imetolewa, thread mpya itaundwa wakati wa mwito wa kwanza na kurudishwa kama sehemu ya majibu.
#
# Vingizo vya Mtumiaji: `user_inputs = ["..."]`: Hufafanua orodha ya vingizo vya mtumiaji ambavyo wakala atashughulikia.
#
# Katika sehemu ya mwisho, futa thread na wakala ili kusafisha rasilimali.

# %% [markdown]
# # Uthibitishaji
#
# Darasa la `DefaultAzureCredential` ni sehemu ya Azure SDK kwa Python. Linatoa njia ya kawaida ya kuthibitisha na huduma za Azure. Linajaribu kuthibitisha kwa kutumia mbinu mbalimbali kwa mpangilio maalum, kama vile vigezo vya mazingira, utambulisho uliosimamiwa, na hati za Azure CLI.
#
# Operesheni za Asynchronous: Moduli ya aio inaonyesha kuwa darasa la DefaultAzureCredential linaunga mkono operesheni za asynchronous. Hii inamaanisha unaweza kuitumia na asyncio kufanya maombi ya uthibitishaji yasiyozuia.

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# **Kanusho**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kuhakikisha usahihi, tafadhali fahamu kuwa tafsiri za kiotomatiki zinaweza kuwa na makosa au kutokuwa sahihi. Hati asilia katika lugha yake ya awali inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu ya binadamu inapendekezwa. Hatutawajibika kwa kutoelewana au tafsiri zisizo sahihi zinazotokana na matumizi ya tafsiri hii.
