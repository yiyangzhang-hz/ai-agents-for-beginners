# %% [markdown]
# # ဥပမာ ဟိုတယ်နှင့် လေယာဉ်စာရင်းလုပ်ဆောင်ရေး ကိုယ်စားလှယ်
#
# ဒီဖြေရှင်းနည်းက သင့်ကို လေယာဉ်လက်မှတ်များနှင့် ဟိုတယ်စာရင်းများကို စီစဉ်ပေးမှာဖြစ်ပါတယ်။ ဒီအခြေအနေမှာတော့ 2024 ဖေဖော်ဝါရီ 20 ရက်နေ့တွင် လန်ဒန် Heathrow (LHR) မှ နယူးယောက် JFK သို့ သွားပြီး 2025 ဖေဖော်ဝါရီ 27 ရက်နေ့တွင် ပြန်လာမည့် ခရီးစဉ်ဖြစ်ပါတယ်။ British Airways ဖြင့်သာ စီးနင်းပြီး အဆင့်သက်သာသော စီးပွားရေးခရီးစဉ်ဖြစ်ပါတယ်။ နယူးယောက်ရှိ Hilton ဟိုတယ်တွင် တည်းခိုလိုပါသည်။ ကျေးဇူးပြု၍ လေယာဉ်နှင့် ဟိုတယ်အတွက် ကုန်ကျစရိတ်များကို ပေးပို့ပေးပါ။

# %% [markdown]
# # Azure AI Agent Service ကို Initialize လုပ်ပြီး **.env** မှ Configuration အချက်အလက်များရယူရန်
#
# ### **.env**
#
# **.env** ဖိုင်တစ်ခု ဖန်တီးပါ။
#
# **.env** တွင် Azure AI Agent Service ၏ connection string, AOAI အသုံးပြုမည့် model, နှင့် ဆက်စပ် Google API Search service API, ENDPOINT စသည်တို့ ပါဝင်သည်။
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "သင့် Azure AI Agent Service Model Deployment Name"
#
# [**NOTE**] သင့်တွင် 100,000 Rate Limit (Tokens per minute) နှင့် 600 Rate Limit (Request per minute) ရှိသော model တစ်ခု လိုအပ်ပါမည်။
#
#   သင်သည် Azure AI Foundry - Model and Endpoint တွင် model ရနိုင်ပါသည်။
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "သင့် Azure AI Agent Service Project Connection String"
#
#   သင်၏ project overview တွင် AI Foundry Portal Screen မှ project connection string ရနိုင်ပါသည်။
#
# - **SERPAPI_SEARCH_API_KEY** = "သင့် SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "သင့် SERPAPI Search Endpoint"
#
# Azure AI Agent Service ၏ Model Deployment Name နှင့် Project Connection String ရရန်အတွက် Azure AI Agent Service တစ်ခု ဖန်တီးရန် လိုအပ်ပါသည်။ [ဒီ template](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) ကို အသုံးပြု၍ တိုက်ရိုက် ဖန်တီးရန် အကြံပြုပါသည်။ （***မှတ်ချက်:*** Azure AI Agent Service သည် လက်ရှိတွင် ကန့်သတ်ထားသော ဒေသများတွင်သာ ရရှိနိုင်ပါသည်။ [ဒီ link](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) ကို ကိုးကား၍ ဒေသကို သတ်မှတ်ရန် အကြံပြုပါသည်။）
#
# Agent သည် SERPAPI ကို access လုပ်ရန် လိုအပ်ပါသည်။ [ဒီ link](https://serpapi.com/searches) ကို အသုံးပြု၍ မှတ်ပုံတင်ရန် အကြံပြုပါသည်။ မှတ်ပုံတင်ပြီးနောက် သင့်အတွက် ထူးခြားသော API KEY နှင့် ENDPOINT ရနိုင်ပါသည်။

# %% [markdown]
# # စတင်ခြင်း
#
# ဒီ notebook ကို run ဖို့အတွက် `pip install -r requirements.txt` ကို run လုပ်ပြီး လိုအပ်တဲ့ library တွေကို install လုပ်ထားရပါမယ်။

# %%
from semantic_kernel import __version__

__version__

# %% [markdown]
# သင့် Semantic Kernel ဗားရှင်းသည် အနည်းဆုံး 1.27.2 ဖြစ်ရမည်။

# %% [markdown]
# သင့် .env ဖိုင် အဆင့်သတ်မှတ်ချက်များနှင့် အရင်းအမြစ်များကို Load လုပ်ပါ၊ သင့်ရဲ့ key များနှင့် အဆင့်သတ်မှတ်ချက်များကို ထည့်သွင်းပြီး၊ ဒေသခံ .env ဖိုင်ကို ဖန်တီးထားရှိသည်ကို သေချာပါ။

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# %% [markdown]
# # Azure သို့ ဝင်ရောက်ရန်
#
# ယခုအချိန်တွင် Azure သို့ ဝင်ရောက်ရန် လိုအပ်ပါသည်။ Terminal ကို ဖွင့်ပြီး အောက်ပါ command ကို ရိုက်ထည့်ပါ-
#
# ```bash
# az login
# ```
#
# ဤ command သည် သင့်အား Azure အကောင့်အချက်အလက်များကို ထည့်ရန် တိုက်တွန်းမည်ဖြစ်ပြီး၊ Azure AI Agent ဝန်ဆောင်မှုကို မှန်ကန်စွာ လုပ်ဆောင်နိုင်ရန် အထောက်အကူပြုမည်ဖြစ်သည်။

# %% [markdown]
# # ရှင်းလင်းချက်:
# ဒီဟာက SERP (Search Engine Results Page) API ဝန်ဆောင်မှုကို အသုံးပြုဖို့ API key ကို သိမ်းဆည်းထားတဲ့ variable တစ်ခုဖြစ်ပါတယ်။ API key ဆိုတာ သင့်အကောင့်နဲ့ ဆက်စပ်ထားတဲ့ တောင်းဆိုမှုတွေကို အတည်ပြုဖို့ အသုံးပြုတဲ့ တစ်ခုတည်းသော အမှတ်အသားဖြစ်ပါတယ်။
#
# ရည်ရွယ်ချက်: ဒီလိုင်းရဲ့ ရည်ရွယ်ချက်က API key ကို variable ထဲမှာ သိမ်းဆည်းထားပြီး SERP API ဝန်ဆောင်မှုကို authenticate လုပ်ဖို့ အသုံးပြုနိုင်ဖို့ ဖြစ်ပါတယ်။ API key က ဝန်ဆောင်မှုကို အသုံးပြုဖို့နဲ့ ရှာဖွေမှုတွေကို လုပ်ဆောင်ဖို့ လိုအပ်ပါတယ်။
# SERP API Key ရယူနည်း: SERP API key ရယူဖို့အတွက် https://serpapi.com မှာ အောက်ပါ အခြေခံလမ်းညွှန်အတိုင်း လိုက်နာပါ (သင့်အသုံးပြုနေတဲ့ SERP API ဝန်ဆောင်မှုအပေါ် မူတည်ပြီး အတိအကျ လုပ်ဆောင်မှုတွေက ကွဲပြားနိုင်ပါတယ်)။
#
# SERP API ဝန်ဆောင်မှုကို ရွေးချယ်ပါ: SerpAPI, Google Custom Search JSON API နဲ့ အခြားဝန်ဆောင်မှုတွေလို SERP API ဝန်ဆောင်မှုအမျိုးမျိုး ရှိပါတယ်။ သင့်လိုအပ်ချက်နဲ့ အတူတူတဲ့ ဝန်ဆောင်မှုကို ရွေးချယ်ပါ။
#
# အကောင့်အတွက် စာရင်းသွင်းပါ: ရွေးချယ်ထားတဲ့ SERP API ဝန်ဆောင်မှုရဲ့ ဝက်ဘ်ဆိုဒ်ကို သွားပြီး အကောင့်အတွက် စာရင်းသွင်းပါ။ အခြေခံအချက်အလက်တွေကို ဖြည့်စွက်ရနိုင်ပြီး သင့်အီးမေးလ်လိပ်စာကို အတည်ပြုရနိုင်ပါတယ်။
#
# API Key တစ်ခု ဖန်တီးပါ: စာရင်းသွင်းပြီးနောက် သင့်အကောင့်ကို ဝင်ရောက်ပြီး API အပိုင်း သို့မဟုတ် dashboard ကို သွားပါ။ API key အသစ်တစ်ခု ဖန်တီးရန် သို့မဟုတ် ထုတ်လုပ်ရန် ရှာဖွေပါ။
# API Key ကို သင့် .env ဖိုင်ထဲကို ကူးထည့်ပါ။

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # ရှင်းလင်းချက်:
# BASE_URL: ဒီဟာက SERP API endpoint အတွက် အခြေခံ URL ကို သိမ်းဆည်းထားတဲ့ variable တစ်ခုဖြစ်ပါတယ်။ BASE_URL ဆိုတဲ့ variable နာမည်ကို API request တွေကို စတင်လုပ်ဆောင်ဖို့ အခြေခံနေရာကို ပြသဖို့အတွက် သုံးတဲ့ စံနာမည်တစ်ခုအဖြစ် သတ်မှတ်ထားတာပါ။
# 'https://serpapi.com/search':
#
# ဒီဟာက BASE_URL variable ကို ပေးထားတဲ့ အမှန်တကယ် URL string ဖြစ်ပါတယ်။ ဒါက SERP API ကို သုံးပြီး ရှာဖွေမှု query တွေကို လုပ်ဆောင်ဖို့ endpoint ကို ကိုယ်စားပြုပါတယ်။
#
# # ရည်ရွယ်ချက်:
# ဒီလို လိုင်းတစ်ခုရေးသားထားတဲ့ ရည်ရွယ်ချက်က SERP API အတွက် အခြေခံ URL ကို သိမ်းဆည်းထားတဲ့ constant တစ်ခုကို သတ်မှတ်ဖို့ ဖြစ်ပါတယ်။ ဒီ URL ကို ရှာဖွေမှု လုပ်ဆောင်ချက်တွေကို လုပ်ဆောင်ဖို့ API request တွေကို တည်ဆောက်ရာမှာ အခြေခံနေရာအဖြစ် အသုံးပြုမှာ ဖြစ်ပါတယ်။
#
# # အသုံးပြုမှု:
# အခြေခံ URL ကို variable အနေနဲ့ သတ်မှတ်ထားခြင်းအားဖြင့် SERP API ကို request လုပ်ဖို့ လိုအပ်တဲ့အခါမှာ သင့် code တစ်ခုလုံးမှာ အလွယ်တကူ ပြန်လည်အသုံးပြုနိုင်ပါတယ်။ ဒီလိုလုပ်ခြင်းက သင့် code ကို ပိုမိုပြုပြင်ထိန်းသိမ်းရလွယ်ကူစေပြီး URL ကို နေရာစုံမှာ တိုက်ရိုက်ရေးသားရင်းမှ ဖြစ်နိုင်တဲ့ အမှားတွေကို လျှော့ချနိုင်ပါတယ်။ လက်ရှိ ဥပမာက https://serpapi.com/search?engine=bing ဖြစ်ပြီး Bing ရှာဖွေမှု API ကို အသုံးပြုထားတာဖြစ်ပါတယ်။ အခြား API တစ်ခုကို https://Serpapi.com မှာ ရွေးချယ်နိုင်ပါတယ်။

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # ရှင်းလင်းချက်:
#
# ဒီနေရာမှာ သင့် Plugin ကုဒ်တွေ ရှိပါတယ်။
#
# Class Definition: `class BookingPlugin`: `BookingPlugin` လို့ခေါ်တဲ့ class တစ်ခုကို သတ်မှတ်ထားပြီး ဟိုတယ်နဲ့ လေယာဉ်များကို ကြိုတင်မှာကြားဖို့ method တွေ ပါဝင်ပါတယ်။
#
# ဟိုတယ် ကြိုတင်မှာကြားမှု Method:
#
# - `@kernel_function(description="booking hotel")`: ဟိုတယ်ကြိုတင်မှာကြားမှုအတွက် kernel function တစ်ခုအဖြစ် function ကို ဖော်ပြတဲ့ decorator တစ်ခု။
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: ဟိုတယ်ကြိုတင်မှာကြားမှုအတွက် parameter တွေနဲ့ return type ကို ဖော်ပြထားတဲ့ method တစ်ခုကို သတ်မှတ်ထားပါတယ်။
#
# ဒီ method က ဟိုတယ်ကြိုတင်မှာကြားမှုအတွက် parameter တွေကို dictionary အဖြစ် ဖွဲ့စည်းပြီး SERP API ကို GET request ပို့ပါတယ်။ Response status ကို စစ်ဆေးပြီး အောင်မြင်ခဲ့ရင် ဟိုတယ် property တွေကို ပြန်ပေးပို့မယ်၊ မအောင်မြင်ခဲ့ရင် None ကို ပြန်ပေးပို့မယ်။
#
# လေယာဉ် ကြိုတင်မှာကြားမှု Method:
#
# - `@kernel_function(description="booking flight")`: လေယာဉ်ကြိုတင်မှာကြားမှုအတွက် kernel function တစ်ခုအဖြစ် function ကို ဖော်ပြတဲ့ decorator တစ်ခု။
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: လေယာဉ်ကြိုတင်မှာကြားမှုအတွက် parameter တွေနဲ့ return type ကို ဖော်ပြထားတဲ့ method တစ်ခုကို သတ်မှတ်ထားပါတယ်။
#
# ဒီ method က outbound နဲ့ return လေယာဉ်ကြိုတင်မှာကြားမှုအတွက် parameter တွေကို dictionary အဖြစ် ဖွဲ့စည်းပြီး SERP API ကို GET request ပို့ပါတယ်။ Response status ကို စစ်ဆေးပြီး အောင်မြင်ခဲ့ရင် လေယာဉ်အချက်အလက်တွေကို result string ထဲမှာ ထည့်သွင်းပေးမယ်၊ မအောင်မြင်ခဲ့ရင် error message တစ်ခုကို print လုပ်ပေးမယ်။ Method က လေယာဉ်အချက်အလက်တွေ ပါဝင်တဲ့ result string ကို ပြန်ပေးပို့မယ်။

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # ရှင်းပြချက်:
# Import Statements: Azure credentials, AI agent, chat message content, author role, kernel function decorator တို့အတွက် လိုအပ်သော module များကို import လုပ်ပါ။
#
# Asynchronous Context Manager: `async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,)`: ဒီဟာက Azure credentials ကို စီမံခန့်ခွဲပြီး AI agent client တစ်ခုကို ဖန်တီးဖို့ asynchronous context manager တစ်ခုကို သတ်မှတ်ပေးပါတယ်။
#
# Agent Name and Instructions:
# - `AGENT_NAME = "BookingAgent"`: Agent ရဲ့ အမည်ကို သတ်မှတ်ပေးပါတယ်။
# - `AGENT_INSTRUCTIONS = """..."""`: Booking request များကို ဘယ်လို ကိုင်တွယ်ရမယ်ဆိုတာအတွက် agent ကို အသေးစိတ်ညွှန်ကြားချက်များပေးထားပါတယ်။
#
# Create Agent Definition: `agent_definition = await client.agents.create_agent(...)`: သတ်မှတ်ထားသော model, name, နှင့် instructions များဖြင့် agent definition တစ်ခုကို ဖန်တီးပါ။
#
# Create AzureAI Agent: `agent = AzureAIAgent(...)`: Client, agent definition, နှင့် သတ်မှတ်ထားသော plugin ကို အသုံးပြုပြီး AzureAI agent တစ်ခုကို ဖန်တီးပါ။
#
# Create Thread: `thread: AzureAIAgentThread | None = None`: Agent အတွက် thread တစ်ခုကို ဖန်တီးပါ။ Thread ကို မဖန်တီးဖို့လိုအပ်ပါက `None` ကို သတ်မှတ်နိုင်ပြီး၊ ပထမဆုံးခေါ်ယူမှုအတွင်းမှာ အသစ်တစ်ခု ဖန်တီးပြီး ပြန်ပေးပို့ပါမည်။
#
# User Inputs: `user_inputs = ["..."]`: Agent အတွက် လုပ်ဆောင်ရန် process လုပ်မည့် user inputs များကို သတ်မှတ်ပါ။
#
# Finally block အတွင်းမှာ၊ resource များကို သန့်ရှင်းစွာ ပြန်လည်ဖျက်သိမ်းရန် thread နှင့် agent ကို ဖျက်ပါ။

# %% [markdown]
# # အတည်ပြုမှု
#
# `DefaultAzureCredential` class သည် Azure SDK for Python ၏ အစိတ်အပိုင်းတစ်ခုဖြစ်သည်။ ၎င်းသည် Azure ဝန်ဆောင်မှုများနှင့် authentication ပြုလုပ်ရန် ပုံမှန်နည်းလမ်းတစ်ခုကို ပံ့ပိုးပေးသည်။ ၎င်းသည် environment variables, managed identity, နှင့် Azure CLI credentials ကဲ့သို့သော နည်းလမ်းများကို အထူးအစီအစဉ်အတိုင်း အသုံးပြု၍ authentication ပြုလုပ်ရန် ကြိုးစားသည်။
#
# အဆင့်ဆင့်လုပ်ဆောင်မှုများ: aio module သည် DefaultAzureCredential class သည် asynchronous operations များကို ပံ့ပိုးပေးသည်ကို ဖော်ပြသည်။ ၎င်းအတွက် asyncio ကို အသုံးပြု၍ blocking မဖြစ်သော authentication requests များကို လုပ်ဆောင်နိုင်သည်။

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)

# %% [markdown]
# ---
#
# **အကြောင်းကြားချက်**:
# ဤစာရွက်စာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) ကို အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှုအတွက် ကြိုးစားနေသော်လည်း၊ အလိုအလျောက် ဘာသာပြန်ခြင်းတွင် အမှားများ သို့မဟုတ် မမှန်ကန်မှုများ ပါရှိနိုင်သည်ကို သတိပြုပါ။ မူရင်းဘာသာစကားဖြင့် ရေးသားထားသော စာရွက်စာတမ်းကို အာဏာရှိသော ရင်းမြစ်အဖြစ် သတ်မှတ်သင့်ပါသည်။ အရေးကြီးသော အချက်အလက်များအတွက် လူ့ဘာသာပြန်ပညာရှင်များမှ ပရော်ဖက်ရှင်နယ် ဘာသာပြန်ခြင်းကို အကြံပြုပါသည်။ ဤဘာသာပြန်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော အလွဲအလွတ်များ သို့မဟုတ် အနားလွဲမှုများအတွက် ကျွန်ုပ်တို့သည် တာဝန်မယူပါ။
